# %%
from scipy import stats

# 월별 전기생산비용(억원)
X = [3.52, 2.58, 3.31, 4.07, 4.62, 3.98, 4.29, 4.83, 3.71, 4.61, 3.90, 3.20]

# 월별 전기 사용량(백만kwh)
y = [2.48, 2.27, 2.47, 2.77, 2.98, 3.05, 3.18, 3.46, 3.03, 3.25, 2.67, 2.53]

############################
result = stats.linregress(X, y)
result
############################
# Out:
# LinregressResult(slope=np.float64(0.4956032360182905), intercept=np.float64(0.9195814280689418), rvalue=np.float64(0.8929235125385305), pvalue=np.float64(9.238421943157891e-05), stderr=np.float64(0.07901935226531728), intercept_stderr=np.float64(0.3110591892275586))

# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
import numpy as np

font_name = font_manager.FontProperties(fname = 'c:/Windows/Fonts/malgun.ttf').get_name()
rc('font', family = font_name)

plt.scatter(X, y)
x1 = np.array(X)
slope, intercept, r_value, p_value, stderr = stats.linregress(X, y)
plt.plot(x1, slope*x1 + intercept, c = 'red')
plt.xlabel('전기생산비용')
plt.ylabel('전기사용량')
plt.show()

############################
# 전기생산비용이 4억원일 때 전기사용량 예측
4 * slope + intercept
# Out:
# np.float64(2.901994372142104)

# %%
#a = [10, 20, 30, 40, 50]
#print(a*5)
# for i in a :
#     print(i*5, end = " ")
a = np.array([10, 20, 30, 40, 50])   #리스트 ===> 넘파이 배열
print(a + 10)
# Out:
# [20 30 40 50 60]
